# %%
from pydoc import describe

import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
data_path =Path("E:/coding/Projects/data")
for file_path in data_path.iterdir():
    print(file_path)
# Out:
# E:\coding\Projects\data\Plant_1_Generation_Data.csv
# E:\coding\Projects\data\Plant_1_Weather_Sensor_Data.csv
# E:\coding\Projects\data\Plant_2_Generation_Data.csv
# E:\coding\Projects\data\Plant_2_Weather_Sensor_Data.csv

# %%
gen_data1= pd.read_csv("E:/coding/Projects/data/Plant_1_Generation_Data.csv")
gen_data2 = pd.read_csv("E:/coding/Projects/data/Plant_2_Generation_Data.csv")
wtr_data1 = pd.read_csv("E:/coding/Projects/data/Plant_1_Weather_Sensor_Data.csv")
wtr_data2 = pd.read_csv("E:/coding/Projects/data/Plant_2_Weather_Sensor_Data.csv")

# %%
print('gen_data1')
print(gen_data1.columns)
print('gen_data2')
print(gen_data2.columns)
print('wtr_data1')
print(wtr_data1.columns)
print('wtr_data2')
print(wtr_data1.columns)
# Out:
# gen_data1
# Index(['DATE_TIME', 'PLANT_ID', 'SOURCE_KEY', 'DC_POWER', 'AC_POWER',
#        'DAILY_YIELD', 'TOTAL_YIELD'],
#       dtype='str')
# gen_data2
# Index(['DATE_TIME', 'PLANT_ID', 'SOURCE_KEY', 'DC_POWER', 'AC_POWER',
#        'DAILY_YIELD', 'TOTAL_YIELD'],
#       dtype='str')
# wtr_data1
# Index(['DATE_TIME', 'PLANT_ID', 'SOURCE_KEY', 'AMBIENT_TEMPERATURE',
#        'MODULE_TEMPERATURE', 'IRRADIATION'],
#       dtype='str')
# wtr_data2
# Index(['DATE_TIME', 'PLANT_ID', 'SOURCE_KEY', 'AMBIENT_TEMPERATURE',
#        'MODULE_TEMPERATURE', 'IRRADIATION'],
#       dtype='str')

# %%
print('gen_data1')
print(gen_data1.describe())
print('gen_data2')
print(gen_data2.describe())
print('wtr_data1')
print(wtr_data1.describe())
print('wtr_data2')
# Out:
# gen_data1
#         PLANT_ID      DC_POWER      AC_POWER   DAILY_YIELD   TOTAL_YIELD
# count    68778.0  68778.000000  68778.000000  68778.000000  6.877800e+04
# mean   4135001.0   3147.426211    307.802752   3295.968737  6.978712e+06
# std          0.0   4036.457169    394.396439   3145.178309  4.162720e+05
# min    4135001.0      0.000000      0.000000      0.000000  6.183645e+06
# 25%    4135001.0      0.000000      0.000000      0.000000  6.512003e+06
# 50%    4135001.0    429.000000     41.493750   2658.714286  7.146685e+06
# 75%    4135001.0   6366.964286    623.618750   6274.000000  7.268706e+06
# max    4135001.0  14471.125000   1410.950000   9163.000000  7.846821e+06
# gen_data2
#         PLANT_ID      DC_POWER      AC_POWER   DAILY_YIELD   TOTAL_YIELD
# count    67698.0  67698.000000  67698.000000  67698.000000  6.769800e+04
# mean   4136001.0    246.701961    241.277825   3294.890295  6.589448e+08
# std          0.0    370.569597    362.112118   2919.448386  7.296678e+08
# ...
